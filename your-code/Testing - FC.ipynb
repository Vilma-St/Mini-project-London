# %%
import pandas as pd

pop_weight_avg_PM2_5 = pd.read_excel('../../Mini-project-London/data/data-pollution/Population_exceeding_LAEI2016_1_modified.xlsx', sheet_name=1, nrows=34, usecols="A:B")
pop_exceeding_NO2 = pd.read_excel('../../Mini-project-London/data/data-pollution/Population_exceeding_LAEI2016_1_modified.xlsx', sheet_name=0, skiprows = 1, nrows=34, usecols="A:C")

pop_weight_avg_PM2_5.head()
# Out:
#                 Borough  LAEI 2016-PM2.5 Annual Mean (µg/m3)
# 0  Barking and Dagenham                            12.825306
# 1                Barnet                            13.009562
# 2                Bexley                            12.555151
# 3                 Brent                            13.378865
# 4               Bromley                            12.406231

# %%
pop_exceeding_NO2.head()
# Out:
#                 Borough  LAEI 2013-age 0-18-%exceeding  \
# 0        City of London                       1.000000
# 1  Barking and Dagenham                       0.037954
# 2                Barnet                       0.114790
# 3                Bexley                       0.008547
# 4                 Brent                       0.218065
#
#    LAEI 2016-age 0-18-%exceeding
# 0                       1.000000
# 1                       0.016949
# 2                       0.098413
# 3                       0.003344
# 4                       0.213054

# %%
schools_exposure_LAEI_2016 = pd.read_excel('../../Mini-project-London/data/data-pollution/Schools_exceeding_LAEI_2016_2-modified.xlsx', sheet_name=0, usecols="A:E")
schools_exposure_LAEI_2016
# Out:
#          URN Local Authority name Phase Of Education  \
# 0     100000       City of London            Primary
# 1     100001       City of London     Not applicable
# 2     100002       City of London     Not applicable
# 3     100003       City of London     Not applicable
# 4     100005               Camden            Nursery
# ...      ...                  ...                ...
# 3237  137244              Bromley            Primary
# 3238  102268             Havering            Primary
# 3239  142721              Bromley            Primary
# 3240  142234              Bromley            Primary
# 3241  147039              Croydon            16 plus
#
#       NO2 Average 2013 (µg/m3)  NO2 Average 2016 (µg/m3)
# 0                    63.067553                 57.500681
# 1                    44.138383                 46.000775
# 2                    60.945122                 54.810001
# 3                    62.744310                 57.419673
# ...

# %%
emissions_summary = pd.read_excel('../../Mini-project-London/data/data-pollution/LAEI2016_Emissions_Summary-NOxPMCO2_modified.xlsx', sheet_name='MASTER')
emissions_summary.head()
# Out:
#                BOROUGHS   2010 - NOx  2010 - PM10  2010 - PM2.5    2010 - CO2  \
# 0        City of London   674.655753    81.550716     51.377952  2.435691e+05
# 1  Barking and Dagenham  2014.555067   284.939751    161.191428  2.714637e+06
# 2                Barnet  2377.635500   489.213430    231.040182  9.998197e+05
# 3                Bexley  1598.495236   322.206736    165.746865  8.321916e+05
# 4                 Brent  1486.969818   267.010888    143.225724  6.713654e+05
#
#     2013 - NOx  2013 - PM10  2013 - PM2.5     2013 - CO2   2016 - NOx  \
# 0   592.429526    71.099536     46.260556  215131.477645   577.401490
# 1  1104.741969   225.016913    111.470403  662118.310408   909.442140
# 2  2039.141918   437.555449    196.711628  938770.739256  1831.891534
# 3  1418.723008   259.602201    135.257544  534854.947979  2238.084791
# 4  1416.524310   252.370365    125.339717  655693.598597  1419.351353
#
#    2016 - PM10  2016 - PM2.5    2016 - CO2
# ...

# %%
education = pd.read_excel('../../Mini-project-London/data/data-education-modified/education-averages-to-import.xlsx', nrows = 35)
# education = education.drop(labels=0)
# education = education.drop(labels=34)
education = education.rename(columns = {"Area":"BOROUGHS"})
education
# Out:
#                   BOROUGHS  KS1 - % exp  KS1 - % exe  KS2 - % exp  \
# 0           City of London          NaN          NaN          NaN
# 1     Barking and Dagenham      75.3750    21.666667    77.621051
# 2                   Barnet      77.8125    22.000000    80.822327
# 3                   Bexley      80.3750    24.083333    78.909332
# 4                    Brent      74.3750    19.750000    76.357953
# 5                  Bromley      80.3125    26.666667    83.265983
# 6                   Camden      75.4375    19.833333    80.620029
# 7                  Croydon      77.0000    22.083333    76.684537
# 8                   Ealing      74.5000    19.750000    78.802419
# 9                  Enfield      72.1875    18.250000    75.276476
# 10               Greenwich      80.3125    28.250000    80.624296
# 11                 Hackney      80.7500    24.750000    79.805056
# 12  Hammersmith and Fulham      78.7500    24.583333    82.189858
# ...

# %%
import matplotlib.pyplot as plt

education.plot(x = "BOROUGHS",y = ["KS1 - % exp", "2010 - CO2", "2013 - CO2", "2016 - CO2"], kind = "bar", figsize=(12,4))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-f4cb21a54c3d> in <module>
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 education.plot(x = "BOROUGHS",y = ["KS1 - % exp", "2010 - CO2", "2013 - CO2", "2016 - CO2"], kind = "bar", figsize=(12,4))
#       4 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     831
#     832                 # don't overwrite
# --> 833                 data = data[y].copy()
#     834
#     835                 if isinstance(data, ABCSeries):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
# ...

# %%
emissions_summary.plot(x = "BOROUGHS", y = ["2010 - NOx", "2013 - NOx", "2016 - NOx"], kind = "bar", figsize=(12,5))
plt.show()

# %%
emissions_summary.plot(x = "BOROUGHS", y = ["2010 - PM10", "2013 - PM10", "2016 - PM10"], kind = "bar", figsize=(12,5))
plt.show()

# %%
emissions_summary.plot(x = "BOROUGHS", y = ["2010 - PM2.5", "2013 - PM2.5", "2016 - PM2.5"], kind = "bar", figsize=(12,5))
plt.show()

# %%
emissions_summary.plot(x = "BOROUGHS", y = [], kind = "bar", figsize=(12,5))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-7f70ab105705> in <module>
# ----> 1 emissions_summary.plot(x = "BOROUGHS", y = [], kind = "bar", figsize=(12,5))
#       2 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ...

# %%
new = pd.merge( emissions_summary, education, on="BOROUGHS", how="left")
new
# Out:
#                   BOROUGHS   2010 - NOx  2010 - PM10  2010 - PM2.5  \
# 0           City of London   674.655753    81.550716     51.377952
# 1     Barking and Dagenham  2014.555067   284.939751    161.191428
# 2                   Barnet  2377.635500   489.213430    231.040182
# 3                   Bexley  1598.495236   322.206736    165.746865
# 4                    Brent  1486.969818   267.010888    143.225724
# 5                  Bromley  1788.087263   435.810021    209.870227
# 6                   Camden  1436.977408   199.941701    121.112263
# 7                  Croydon  1635.264600   313.617132    172.092184
# 8                   Ealing  2002.689067   353.731910    192.431127
# 9                  Enfield  3291.932563   437.575923    216.050074
# 10               Greenwich  1911.225776   485.646608    201.566307
# 11                 Hackney   995.853542   204.336427     96.062989
# 12  Hammersmith and Fulham   928.748844   133.839778     79.093975
# ...

# %%
# Corr() seems to work fine with merged data frame

correlation = new.corr(method ='pearson')
correlation
# Out:
#                     2010 - NOx  2010 - PM10  2010 - PM2.5  2010 - CO2  \
# 2010 - NOx            1.000000     0.887802      0.917104    0.708273
# 2010 - PM10           0.887802     1.000000      0.975518    0.597554
# 2010 - PM2.5          0.917104     0.975518      1.000000    0.648386
# 2010 - CO2            0.708273     0.597554      0.648386    1.000000
# 2013 - NOx            0.985883     0.872590      0.899070    0.599876
# 2013 - PM10           0.867569     0.975206      0.963017    0.546627
# 2013 - PM2.5          0.890641     0.951996      0.986174    0.563806
# 2013 - CO2            0.929275     0.821545      0.862188    0.741266
# 2016 - NOx            0.958335     0.843988      0.875492    0.588667
# 2016 - PM10           0.872380     0.968494      0.973545    0.598324
# 2016 - PM2.5          0.895055     0.937479      0.980720    0.583404
# 2016 - CO2            0.648165     0.628320      0.656075    0.498291
# ...

# %%
new.plot(x = "BOROUGHS",y = ["KS1 - % exp", "KS2 - % exp", "GCSE - Av Attain 8"], kind = "bar", figsize=(12,4))
plt.show()

# %%
new.head()
# Out:
#                BOROUGHS   2010 - NOx  2010 - PM10  2010 - PM2.5    2010 - CO2  \
# 0        City of London   674.655753    81.550716     51.377952  2.435691e+05
# 1  Barking and Dagenham  2014.555067   284.939751    161.191428  2.714637e+06
# 2                Barnet  2377.635500   489.213430    231.040182  9.998197e+05
# 3                Bexley  1598.495236   322.206736    165.746865  8.321916e+05
# 4                 Brent  1486.969818   267.010888    143.225724  6.713654e+05
#
#     2013 - NOx  2013 - PM10  2013 - PM2.5     2013 - CO2   2016 - NOx  ...  \
# 0   592.429526    71.099536     46.260556  215131.477645   577.401490  ...
# 1  1104.741969   225.016913    111.470403  662118.310408   909.442140  ...
# 2  2039.141918   437.555449    196.711628  938770.739256  1831.891534  ...
# 3  1418.723008   259.602201    135.257544  534854.947979  2238.084791  ...
# 4  1416.524310   252.370365    125.339717  655693.598597  1419.351353  ...
#
# ...

# %%
fig, edu1 = plt.subplots()
edu1.set_xlabel('KS1/2 % pupils exp grade')
edu1.set_ylabel('Borough')
edu1.plot(new["BOROUGHS"], new[["KS1 - % exp","KS2 - % exp"]])
edu1.tick_params(axis='y')

edu2 = edu1.twinx()  # instantiate a second axes that shares the same x-axis

edu2.set_ylabel("GCSE - Av attain 8")  # we already handled the x-label with ax1
edu2.plot(new["BOROUGHS"], new["GCSE - Av Attain 8"])
edu2.tick_params(axis='y')

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from io import StringIO

s = StringIO("""     amount     price
A     40929   4066443
B     93904   9611272
C    188349  19360005
D    248438  24335536
E    205622  18888604
F    140173  12580900
G     76243   6751731
H     36859   3418329
I     29304   2758928
J     39768   3201269
K     30350   2867059""")

df = pd.read_csv(s, index_col=0, delimiter=' ', skipinitialspace=True)

fig = plt.figure() # Create matplotlib figure

ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.

width = 0.4

df["amount"].plot(kind='bar', color='red', ax=ax, width=width, position=1)
df.price.plot(kind='bar', color='blue', ax=ax2, width=width, position=0)

ax.set_ylabel('Amount')
ax2.set_ylabel('Price')

plt.show()
df.head()
# Out:
#    amount     price
# A   40929   4066443
# B   93904   9611272
# C  188349  19360005
# D  248438  24335536
# E  205622  18888604

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# from io import StringIO

# s = StringIO("""     amount     price
# A     40929   4066443
# B     93904   9611272
# C    188349  19360005
# D    248438  24335536
# E    205622  18888604
# F    140173  12580900
# G     76243   6751731
# H     36859   3418329
# I     29304   2758928
# J     39768   3201269
# K     30350   2867059""")

# df = pd.read_csv(s, index_col=0, delimiter=' ', skipinitialspace=True)

fig = plt.figure() # Create matplotlib figure

ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.
# plt.xlabel(new["BOUROUGHS"])
width = 0.4

new["KS1 - % exp"].plot(kind='bar', color='red', ax=ax, width=width, position=1)
new["KS2 - % exp"].plot(kind='bar', color='red', ax=ax, width=width, position=0.5)
new["GCSE - Av Attain 8"].plot(kind='bar', color='blue', ax=ax2, width=width, position=0)

ax.set_ylabel("KS1/2 % pupils exp grade")
ax2.set_ylabel("GCSE - Av attain 8")

plt.show()
