# %%
import pandas as pd

ks2cols = ["URN", "SCHNAME", "PTKS1GROUP_M", "PTKS1GROUP_H", "PTREAD_EXP" ,"PTREAD_HIGH", "PTGPS_EXP", "PTGPS_HIGH",
          "PTWRITTA_EXP", "PTWRITTA_HIGH", "PTMAT_EXP", "PTMAT_HIGH", "PTRWM_EXP", "PTRWM_HIGH"]
ks4cols = ["URN", "SCHNAME", "ATT8SCR", "P8MEA"]

ks22017 = pd.read_csv('../../Mini-project-London/data/data-education-modified/england_ks2final17.csv', usecols=ks2cols)
ks42017 = pd.read_csv('../../Mini-project-London/data/data-education-modified/england_ks4final17.csv', usecols=ks4cols)
ks22018 = pd.read_csv('../../Mini-project-London/data/data-education-modified/england_ks2final18.csv', usecols=ks2cols)
ks42018 = pd.read_csv('../../Mini-project-London/data/data-education-modified/england_ks4final18.csv', usecols=ks4cols)
ks22019 = pd.read_csv('../../Mini-project-London/data/data-education-modified/england_ks2final19.csv', usecols=ks2cols,
                     nrows = 16355)
ks42019 = pd.read_csv('../../Mini-project-London/data/data-education-modified/england_ks4final19.csv', usecols=ks4cols)


ks2 = pd.concat([ks22017, ks22018, ks22019])
ks2 = 
# ks22 = ks2.groupby(level=1).mean()
# ks22.head()

# ks2 = [ks22017, ks42018, ks22019]
# ks2 = [df.set_index("URN") for df in ks2]
# ks2 = ks2[0].join(ks2[1:])

# ks2.head()

# ks2av = (ks22017 + ks22018 + ks22019)/3
# ks4av = (ks42017 + ks42018 + ks42019)/3
# ks22017.head()
# Out:
# C:\Users\fergu\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           URN                             SCHNAME PTKS1GROUP_M PTKS1GROUP_H  \
# 0      110705  The Duke of Bedford Primary School          61%          35%
# 1      117736          East Halton Primary School          56%          33%
# 2      122638         East Markham Primary School          57%          33%
# 3      141550               Easton Primary School          50%          38%
# 4      142999              Eastwick Junior School          40%          52%
# ...       ...                                 ...          ...          ...
# 16350  126163        Fordwater School, Chichester           0%           0%
# 16351  136114                      Woodlands Meed          30%           5%
# ...
